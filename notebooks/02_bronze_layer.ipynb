# %%
import pandas as pd

# Load 1 file saja (April 2026)
df = pd.read_parquet(r"../data/bronze/yellow_tripdata_2026-04.parquet")

print("Shape:", df.shape)
print("Kolom:", df.columns.tolist())
print("\nMissing values:")
print(df.isnull().sum())

# Simpan ke Bronze
df.to_parquet(r"../data/bronze/yellow_tripdata_2026-04_clean.parquet", index=False)
print("✅ Bronze layer selesai!")
# Out:
# Shape: (3800664, 20)
# Kolom: ['VendorID', 'tpep_pickup_datetime', 'tpep_dropoff_datetime', 'passenger_count', 'trip_distance', 'RatecodeID', 'store_and_fwd_flag', 'PULocationID', 'DOLocationID', 'payment_type', 'fare_amount', 'extra', 'mta_tax', 'tip_amount', 'tolls_amount', 'improvement_surcharge', 'total_amount', 'congestion_surcharge', 'Airport_fee', 'cbd_congestion_fee']
#
# Missing values:
# VendorID                      0
# tpep_pickup_datetime          0
# tpep_dropoff_datetime         0
# passenger_count          799786
# trip_distance                 0
# RatecodeID               799786
# store_and_fwd_flag       799786
# PULocationID                  0
# DOLocationID                  0
# payment_type                  0
# fare_amount                   0
# extra                         0
# mta_tax                       0
# tip_amount                    0
# tolls_amount                  0
# improvement_surcharge         0
# total_amount                  0
# ...
